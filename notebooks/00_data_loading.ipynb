# %%
import pandas as pd
import numpy as np
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
base = PROJECT_ROOT / "data/raw/hdfs/HDFS_v1/preprocessed"

X_if = pd.read_csv(base / "Event_occurrence_matrix.csv")
y = pd.read_csv(base / "anomaly_label.csv")

traces = pd.read_csv(base / "Event_traces.csv")
templates = pd.read_csv(base / "HDFS.log_templates.csv")

print("X_if shape:", X_if.shape)
print("y shape:", y.shape)
print("traces shape:", traces.shape)
print("templates shape:", templates.shape)
# Out:
# X_if shape: (575061, 32)
# y shape: (575061, 2)
# traces shape: (575061, 6)
# templates shape: (29, 2)
